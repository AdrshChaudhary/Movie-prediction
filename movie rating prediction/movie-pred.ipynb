# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('IMDb-Movies.csv', encoding='ISO-8859–1')

# %%
data.head(10)
# Out:
#                                  Name    Year  Duration  \
# 0                                         NaN       NaN
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2                            #Homecog  2021.0      90.0
# 3                             #Yaaram  2019.0     110.0
# 4                   ...And Once Again  2010.0     105.0
# 5                ...Aur Pyaar Ho Gaya  1997.0     147.0
# 6                           ...Yahaan  2005.0     142.0
# 7                      .in for Motion  2008.0      59.0
# 8                  ?: A Question Mark  2012.0      82.0
# 9                            @Andheri  2014.0     116.0
#
#                        Genre  Rating    Votes            Director  \
# 0                      Drama     NaN      NaN       J.S. Randhawa
# 1                      Drama     7.0     8.00       Gaurav Bakshi
# 2             Drama, Musical     NaN      NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4    35.00          Ovais Khan
# 4                      Drama     NaN      NaN        Amol Palekar
# 5     Comedy, Drama, Musical     4.7   827.00        Rahul Rawail
# 6        Drama, Romance, War     7.4  1086.00      Shoojit Sircar
# 7                Documentary     NaN      NaN       Anirban Datta
# 8  Horror, Mystery, Thriller     5.6   326.00       Allyson Patel
# 9    Action, Crime, Thriller     4.0    11.00   Biju Bhaskar Nair
#
#            Actor 1                 Actor 2          Actor 3
# 0         Manmauji                  Birbal  Rajendra Bhatia
# 1     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 2     Sayani Gupta       Plabita Borthakur       Roy Angana
# 3          Prateik              Ishita Raj  Siddhant Kapoor
# 4     Rajat Kapoor      Rituparna Sengupta      Antara Mali
# 5       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Jimmy Sheirgill             issha Lamba   Yashpal Sharma
# 7              NaN                     NaN              NaN
# 8        Yash Dave          Muntazir Ahmad     Kiran Bhatia
# 9        Augustine            Fathima Babu             Byon

# %%
data.tail(10)
# Out:
#                       Name    Year  Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab  1995.0       NaN                Action     NaN
# 15500      Zulm Ka Muqabla  1993.0       NaN                Action     NaN
# 15501      Zulm Ki Hukumat  1992.0       NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar  1979.0       NaN                Action     NaN
# 15503      Zulm Ki Zanjeer  1989.0     125.0  Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga  1988.0       NaN                Action     4.6
# 15505                Zulmi  1999.0     129.0         Action, Drama     4.5
# 15506            Zulmi Raj  2005.0       NaN                Action     NaN
# 15507        Zulmi Shikari  1988.0       NaN                Action     NaN
# 15508           ZulmOSitam  1998.0     130.0         Action, Drama     6.2
#
#         Votes           Director                Actor 1              Actor 2  \
# 15499     NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# 15500     NaN        Babu Antony  Nandamuri Balakrishna          Vijayshanti
# 15501  135.00  Bharat Rangachary             Dharmendra  Moushumi Chatterjee
# 15502     NaN     DineshRamanesh            Ramesh Puri           Jalal Agha
# 15503   44.00    S.P. Muthuraman            Chiranjeevi           Jayamalini
# 15504   11.00      Mahendra Shah       Naseeruddin Shah        Sumeet Saigal
# 15505  655.00         Kuku Kohli           Akshay Kumar       Twinkle Khanna
# 15506     NaN         Kiran Thej        Sangeeta Tiwari                  NaN
# 15507     NaN                NaN                    NaN                  NaN
# 15508   20.00       K.C. Bokadia             Dharmendra           Jaya Prada
#
#              Actor 3
# 15499    Kiran Kumar
# 15500            NaN
# 15501        Govinda
# 15502   Valerie Agha
# 15503    Rajinikanth
# 15504  Suparna Anand
# 15505    Aruna Irani
# 15506            NaN
# 15507            NaN
# 15508    Arjun Sarja

# %%
data.shape
# Out:
# (15509, 10)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 15509
# Number of Columns 10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   float64
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.2+ MB

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %%
data.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
data.Year.unique()
# Out:
# array([2019., 1997., 2005., 2012., 2014., 2004., 2016., 1991., 2018.,
#        2010., 1958., 2021., 2017., 2009., 1993., 2002., 2008., 1994.,
#        2007., 2003., 1998., 1979., 1974., 2015., 2006., 1981., 2020.,
#        1985., 2013., 2011., 1988., 1987., 1999., 1973., 1968., 1982.,
#        1977., 1950., 1969., 1948., 1990., 1989., 2001., 2000., 1953.,
#        1978., 1963., 1992., 1976., 1984., 1986., 1966., 1975., 1980.,
#        1967., 1970., 1952., 1972., 1971., 1964., 1954., 1962., 1957.,
#        1965., 1996., 1995., 1956., 1955., 1936., 1983., 1951., 1961.,
#        1959., 1949., 1960., 1946., 1940., 1945., 1938., 1941., 1942.,
#        1935., 1937., 1947., 1931., 1933., 1943., 1944., 1932., 1939.,
#        1934.])

# %%
data.Rating.unique()
# Out:
# array([ 7. ,  4.4,  4.7,  7.4,  5.6,  4. ,  6.2,  5.9,  6.5,  5.7,  6.3,
#         7.2,  6.6,  7.3,  7.1,  6.9,  3.5,  4.5,  6.4,  4.1,  4.8,  8.1,
#         5.5,  6.8,  5. ,  6.1,  7.7,  5.1,  3.3,  7.8,  8.4,  4.3,  5.8,
#         7.5,  3.6,  4.6,  4.2,  5.3,  5.4,  3. ,  8. ,  6. ,  3.1,  3.8,
#         7.9,  2.7,  2.4,  7.6,  6.7,  3.4,  5.2,  4.9,  2.8,  3.7,  3.9,
#         3.2,  2.9,  8.2,  8.7,  8.3,  9.3,  8.8,  2.1,  2.5,  2.3,  8.5,
#         8.6,  2.6,  1.7,  9. ,  1.4,  8.9,  1.9,  9.4,  9.7,  1.8,  9.2,
#         2. ,  9.1, 10. ,  1.6,  2.2,  1.1])

# %%
def TopTenPlot(column):
    global data
    data[column].value_counts().sort_values(ascending=False)[:10].plot(kind="bar", figsize=(20,6), edgecolor="k")
    plt.xticks(rotation=0)
    plt.title("Top Ten {}".format(column))
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.show()

# %%
def Histogram(column):
    global data
    plt.figure(figsize=(20,6))
    plt.hist(data[column], edgecolor="k")
    plt.xticks(rotation=0)
    plt.title("Histogram of {}".format(column))
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
def Scatter(x, y, c=None):
    global data
    plt.figure(figsize=(20,6))
    plt.scatter(data[x], data[y], edgecolor="k", c=c)
    plt.xticks(rotation=0)
    plt.title("Scatter plot X:{} / Y:{}".format(x, y))
    plt.xlabel(x)
    plt.ylabel(y)
    plt.show()

# %%
TopTenPlot("Director")

# %%
TopTenPlot("Actor 2")

# %%
TopTenPlot("Actor 3")

# %%
sns.pairplot(data)
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = data[numeric_columns].corr(method='spearman')
